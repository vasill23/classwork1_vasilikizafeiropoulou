# %% [markdown]
# <a href="https://colab.research.google.com/github/vasill23/classwork1_vasilikizafeiropoulou/blob/main/data_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/reportd1.csv', delimiter=';')

# %%
df.to_csv('/content/drive/MyDrive/report3.csv.xlsx', index=False)

# %%
df
# Out:
#      type              source  \
# 0     web           e-vima.gr
# 1     web           e-vima.gr
# 2     web       aridaia365.gr
# 3     web      anexartitos.gr
# 4     web  mixanitouxronou.gr
# ...   ...                 ...
# 4999  web        popaganda.gr
# 5000  web       trikaladay.gr
# 5001  web      oparlapipas.gr
# 5002  web       epirusgate.gr
# 5003  web         pandiera.gr
#
#                                                   title  \
# 0     ΤΕΕ/ΤΚΜ: Ημερίδα για τον προσβάσιμο και συμπερ...
# 1     ΠΑΣΟΚ Σερρών: Οι αγρότες των Σερρών δεν θα πλη...
# 2     Κατατέθηκε η πρόταση της ΝΔ για σύσταση Προανα...
# 3     ΝΕ ΠΑΣΟΚ Σερρών: ΟΠΕΚΕΠΕ – Οι αγρότες των Σερρ...
# 4     Για πλημμεληματικές πράξεις του Καραμανλή ζητά...
# ...                                                 ...
# 4999                    Είναι το θέμα μας η δικαιοσύνη;
# 5000  Το κάλεσμα της Μαρίας Καρυστιανού για τις συγκ...
# 5001  H αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...
# 5002  Στ. Κασσελάκης: Οικονομία με λιγότερους φόρους...
# 5003  ΑΝΤΑΡΣΥΑ: Όλοι και Όλες στην Γενική Απεργία στ...
#
#                                                    text            categories  \
# 0     Ημερίδα για τον σχεδιασμό φιλικών, προσβάσιμων...  διαφθορά στην Ελλάδα
# 1     Ο εύφορος κάμπος των Σερρών, που αποτελεί πηγή...  διαφθορά στην Ελλάδα
# 2     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ\nΚατατ...  διαφθορά στην Ελλάδα
# 3     By\nανεξάρτητος\non\n27 Μαΐου 2025\nNo Comment...  διαφθορά στην Ελλάδα
# 4     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ για σύ...  διαφθορά στην Ελλάδα
# ...                                                 ...                   ...
# 4999  “Αν θέλουν να έρθουν στη Βουλή, ας έρθουν να δ...  διαφθορά στην Ελλάδα
# 5000  «28/02/2025 είναι μια μέρα μνήμης… είναι η μέρ...  διαφθορά στην Ελλάδα
# 5001  Η αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...  διαφθορά στην Ελλάδα
# 5002  Ο Πρόεδρος του Κινήματος Δημοκρατίας, Στέφανος...  διαφθορά στην Ελλάδα
# 5003  ΚΑΤΩ Η ΚΥΒΕΡΝΗΣΗ ΚΑΙ Η ΠΟΛΙΤΙΚΗ ΤΟΥ ΕΓΚΛΗΜΑΤΟΣ...  διαφθορά στην Ελλάδα
#
#      sentiment       date      time  \
# 0     Positive  27/5/2025  20:34:45
# 1      Neutral  27/5/2025  20:06:13
# 2      Neutral  27/5/2025  19:43:37
# 3      Neutral  27/5/2025  19:40:23
# 4      Neutral  27/5/2025  18:55:25
# ...        ...        ...       ...
# 4999  Negative  24/2/2025   0:00:00
# 5000   Neutral  23/2/2025  22:32:00
# 5001   Neutral  23/2/2025  20:03:14
# 5002  Positive  23/2/2025  19:02:33
# 5003   Neutral  23/2/2025  17:49:34
#
#                                                    link
# 0     https://www.e-vima.gr/tee-tkm-imerida-gia-ton-...
# 1     https://www.e-vima.gr/pasok-serron-oi-agrotes-...
# 2     https://www.aridaia365.gr/2025/05/blog-post_90...
# 3     https://www.anexartitos.gr/ne-pasok-serron-ope...
# 4     https://www.mixanitouxronou.gr/gia-plimmelimat...
# ...                                                 ...
# 4999  https://popaganda.gr/postscripts/einai-to-them...
# 5000  https://www.trikaladay.gr/to-kalesma-tis-maria...
# 5001  https://www.oparlapipas.gr/2025/02/h-k_0122596...
# 5002  https://epirusgate.gr/st-kasselakis-oikonomia-...
# 5003  https://pandiera.gr/%ce%b1%ce%bd%cf%84%ce%b1%c...
#
# [5004 rows x 9 columns]

# %%
df_D= df[df["type"] == "web"].drop_duplicates(subset="title")
df_D
# Out:
#      type              source  \
# 0     web           e-vima.gr
# 1     web           e-vima.gr
# 2     web       aridaia365.gr
# 3     web      anexartitos.gr
# 4     web  mixanitouxronou.gr
# ...   ...                 ...
# 4999  web        popaganda.gr
# 5000  web       trikaladay.gr
# 5001  web      oparlapipas.gr
# 5002  web       epirusgate.gr
# 5003  web         pandiera.gr
#
#                                                   title  \
# 0     ΤΕΕ/ΤΚΜ: Ημερίδα για τον προσβάσιμο και συμπερ...
# 1     ΠΑΣΟΚ Σερρών: Οι αγρότες των Σερρών δεν θα πλη...
# 2     Κατατέθηκε η πρόταση της ΝΔ για σύσταση Προανα...
# 3     ΝΕ ΠΑΣΟΚ Σερρών: ΟΠΕΚΕΠΕ – Οι αγρότες των Σερρ...
# 4     Για πλημμεληματικές πράξεις του Καραμανλή ζητά...
# ...                                                 ...
# 4999                    Είναι το θέμα μας η δικαιοσύνη;
# 5000  Το κάλεσμα της Μαρίας Καρυστιανού για τις συγκ...
# 5001  H αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...
# 5002  Στ. Κασσελάκης: Οικονομία με λιγότερους φόρους...
# 5003  ΑΝΤΑΡΣΥΑ: Όλοι και Όλες στην Γενική Απεργία στ...
#
#                                                    text            categories  \
# 0     Ημερίδα για τον σχεδιασμό φιλικών, προσβάσιμων...  διαφθορά στην Ελλάδα
# 1     Ο εύφορος κάμπος των Σερρών, που αποτελεί πηγή...  διαφθορά στην Ελλάδα
# 2     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ\nΚατατ...  διαφθορά στην Ελλάδα
# 3     By\nανεξάρτητος\non\n27 Μαΐου 2025\nNo Comment...  διαφθορά στην Ελλάδα
# 4     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ για σύ...  διαφθορά στην Ελλάδα
# ...                                                 ...                   ...
# 4999  “Αν θέλουν να έρθουν στη Βουλή, ας έρθουν να δ...  διαφθορά στην Ελλάδα
# 5000  «28/02/2025 είναι μια μέρα μνήμης… είναι η μέρ...  διαφθορά στην Ελλάδα
# 5001  Η αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...  διαφθορά στην Ελλάδα
# 5002  Ο Πρόεδρος του Κινήματος Δημοκρατίας, Στέφανος...  διαφθορά στην Ελλάδα
# 5003  ΚΑΤΩ Η ΚΥΒΕΡΝΗΣΗ ΚΑΙ Η ΠΟΛΙΤΙΚΗ ΤΟΥ ΕΓΚΛΗΜΑΤΟΣ...  διαφθορά στην Ελλάδα
#
#      sentiment       date      time  \
# 0     Positive  27/5/2025  20:34:45
# 1      Neutral  27/5/2025  20:06:13
# 2      Neutral  27/5/2025  19:43:37
# 3      Neutral  27/5/2025  19:40:23
# 4      Neutral  27/5/2025  18:55:25
# ...        ...        ...       ...
# 4999  Negative  24/2/2025   0:00:00
# 5000   Neutral  23/2/2025  22:32:00
# 5001   Neutral  23/2/2025  20:03:14
# 5002  Positive  23/2/2025  19:02:33
# 5003   Neutral  23/2/2025  17:49:34
#
#                                                    link
# 0     https://www.e-vima.gr/tee-tkm-imerida-gia-ton-...
# 1     https://www.e-vima.gr/pasok-serron-oi-agrotes-...
# 2     https://www.aridaia365.gr/2025/05/blog-post_90...
# 3     https://www.anexartitos.gr/ne-pasok-serron-ope...
# 4     https://www.mixanitouxronou.gr/gia-plimmelimat...
# ...                                                 ...
# 4999  https://popaganda.gr/postscripts/einai-to-them...
# 5000  https://www.trikaladay.gr/to-kalesma-tis-maria...
# 5001  https://www.oparlapipas.gr/2025/02/h-k_0122596...
# 5002  https://epirusgate.gr/st-kasselakis-oikonomia-...
# 5003  https://pandiera.gr/%ce%b1%ce%bd%cf%84%ce%b1%c...
#
# [3691 rows x 9 columns]

# %%
df_D=df.drop(columns=["categories", "sentiment"])
df_D
# Out:
#      type              source  \
# 0     web           e-vima.gr
# 1     web           e-vima.gr
# 2     web       aridaia365.gr
# 3     web      anexartitos.gr
# 4     web  mixanitouxronou.gr
# ...   ...                 ...
# 4999  web        popaganda.gr
# 5000  web       trikaladay.gr
# 5001  web      oparlapipas.gr
# 5002  web       epirusgate.gr
# 5003  web         pandiera.gr
#
#                                                   title  \
# 0     ΤΕΕ/ΤΚΜ: Ημερίδα για τον προσβάσιμο και συμπερ...
# 1     ΠΑΣΟΚ Σερρών: Οι αγρότες των Σερρών δεν θα πλη...
# 2     Κατατέθηκε η πρόταση της ΝΔ για σύσταση Προανα...
# 3     ΝΕ ΠΑΣΟΚ Σερρών: ΟΠΕΚΕΠΕ – Οι αγρότες των Σερρ...
# 4     Για πλημμεληματικές πράξεις του Καραμανλή ζητά...
# ...                                                 ...
# 4999                    Είναι το θέμα μας η δικαιοσύνη;
# 5000  Το κάλεσμα της Μαρίας Καρυστιανού για τις συγκ...
# 5001  H αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...
# 5002  Στ. Κασσελάκης: Οικονομία με λιγότερους φόρους...
# 5003  ΑΝΤΑΡΣΥΑ: Όλοι και Όλες στην Γενική Απεργία στ...
#
#                                                    text       date      time  \
# 0     Ημερίδα για τον σχεδιασμό φιλικών, προσβάσιμων...  27/5/2025  20:34:45
# 1     Ο εύφορος κάμπος των Σερρών, που αποτελεί πηγή...  27/5/2025  20:06:13
# 2     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ\nΚατατ...  27/5/2025  19:43:37
# 3     By\nανεξάρτητος\non\n27 Μαΐου 2025\nNo Comment...  27/5/2025  19:40:23
# 4     Δόθηκε στη δημοσιότητα η πρόταση της ΝΔ για σύ...  27/5/2025  18:55:25
# ...                                                 ...        ...       ...
# 4999  “Αν θέλουν να έρθουν στη Βουλή, ας έρθουν να δ...  24/2/2025   0:00:00
# 5000  «28/02/2025 είναι μια μέρα μνήμης… είναι η μέρ...  23/2/2025  22:32:00
# 5001  Η αδυναμία της κυβέρνησης της ΝΔ να περιορίσει...  23/2/2025  20:03:14
# 5002  Ο Πρόεδρος του Κινήματος Δημοκρατίας, Στέφανος...  23/2/2025  19:02:33
# 5003  ΚΑΤΩ Η ΚΥΒΕΡΝΗΣΗ ΚΑΙ Η ΠΟΛΙΤΙΚΗ ΤΟΥ ΕΓΚΛΗΜΑΤΟΣ...  23/2/2025  17:49:34
#
#                                                    link
# 0     https://www.e-vima.gr/tee-tkm-imerida-gia-ton-...
# 1     https://www.e-vima.gr/pasok-serron-oi-agrotes-...
# 2     https://www.aridaia365.gr/2025/05/blog-post_90...
# 3     https://www.anexartitos.gr/ne-pasok-serron-ope...
# 4     https://www.mixanitouxronou.gr/gia-plimmelimat...
# ...                                                 ...
# 4999  https://popaganda.gr/postscripts/einai-to-them...
# 5000  https://www.trikaladay.gr/to-kalesma-tis-maria...
# 5001  https://www.oparlapipas.gr/2025/02/h-k_0122596...
# 5002  https://epirusgate.gr/st-kasselakis-oikonomia-...
# 5003  https://pandiera.gr/%ce%b1%ce%bd%cf%84%ce%b1%c...
#
# [3691 rows x 7 columns]

# %%
df_D=
