# %% [markdown]
# <a href="https://colab.research.google.com/github/vasill23/classwork1_vasilikizafeiropoulou/blob/main/cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
import os
from glob import glob

articles = '/content/gdrive/MyDrive/διαφθορα'  # <-- άλλαξε αυτό

csv_files = glob(os.path.join(articles, '*.csv'))

print("Βρέθηκαν αρχεία:", csv_files)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Βρέθηκαν αρχεία: ['/content/gdrive/MyDrive/διαφθορα/jan1-15.csv', '/content/gdrive/MyDrive/διαφθορα/jan16-29.csv', '/content/gdrive/MyDrive/διαφθορα/jan30-31.csv', '/content/gdrive/MyDrive/διαφθορα/feb1-10.csv', '/content/gdrive/MyDrive/διαφθορα/feb11-20.csv', '/content/gdrive/MyDrive/διαφθορα/feb21-27.csv', '/content/gdrive/MyDrive/διαφθορα/feb28-29.csv', '/content/gdrive/MyDrive/διαφθορα/mar1-9.csv', '/content/gdrive/MyDrive/διαφθορα/mar10-17.csv', '/content/gdrive/MyDrive/διαφθορα/mar18-21.csv', '/content/gdrive/MyDrive/διαφθορα/mar22-26.csv', '/content/gdrive/MyDrive/διαφθορα/mar27-28.csv', '/content/gdrive/MyDrive/διαφθορα/mar29-31.csv', '/content/gdrive/MyDrive/διαφθορα/apr1-6.csv', '/content/gdrive/MyDrive/διαφθορα/apr7-12.csv', '/content/gdrive/MyDrive/διαφθορα/apr13-23.csv', '/content/gdrive/MyDrive/διαφθορα/apr24-30.csv', '/content/gdrive/MyDrive/διαφθορα/may1-15.csv', '/content/gdrive/MyDrive/διαφθορα/may16-22.csv', '/content/gdrive/MyDrive/διαφθορα/may23-28.csv', '/content/gdrive/MyDrive/διαφθορα/may29-31.csv', '/content/gdrive/MyDrive/διαφθορα/jun1-10.csv', '/content/gdrive/MyDrive/διαφθορα/jun11-24.csv', '/content/gdrive/MyDrive/διαφθορα/jun25-30.csv', '/content/gdrive/MyDrive/διαφθορα/jul1-12.csv', '/content/gdrive/MyDrive/διαφθορα/jul13-23.csv', '/content/gdrive/MyDrive/διαφθορα/jul24-31.csv', '/content/gdrive/MyDrive/διαφθορα/aug1-15.csv', '/content/gdrive/MyDrive/διαφθορα/aug16-31.csv', '/content/gdrive/MyDrive/διαφθορα/sep1-16.csv', '/content/gdrive/MyDrive/διαφθορα/sep17-30.csv', '/content/gdrive/MyDrive/διαφθορα/oct1-12.csv', '/content/gdrive/MyDrive/διαφθορα/oct13-24.csv', '/content/gdrive/MyDrive/διαφθορα/oct25-31.csv', '/content/gdrive/MyDrive/διαφθορα/nov1-14.csv', '/content/gdrive/MyDrive/διαφθορα/nov15-30.csv', '/content/gdrive/MyDrive/διαφθορα/dec1-12.csv', '/content/gdrive/MyDrive/διαφθορα/dec13-27.csv', '/content/gdrive/MyDrive/διαφθορα/dec28-31.csv']

# %%
df_main = pd.DataFrame()

for file in csv_files:
    try:
        df_temp = pd.read_csv(file,delimiter=';', on_bad_lines='skip')  # Αν έχει προβληματικές γραμμές, θα τις αγνοήσει
        df_temp['/content/gdrive/MyDrive/διαφθορα'] = os.path.basename(file)   # Προσθήκη στήλης με όνομα αρχείου (προαιρετικό αλλά χρήσιμο)
        df_main = pd.concat([df_main, df_temp], ignore_index=True)
    except Exception as e:
        print(f"Πρόβλημα στο αρχείο {file}: {e}")

# %%
df_main
# Out:
#        type            source  \
# 0       web        iapopsi.gr
# 1       web          sfina.gr
# 2       web  pentapostagma.gr
# 3       web    sportrikala.gr
# 4       web    thestandard.gr
# ...     ...               ...
# 166396  web         syriza.gr
# 166397  web         syriza.gr
# 166398  web    imerodromos.gr
# 166399  web       epiloges.tv
# 166400  web    athens-news.gr
#
#                                                     title  \
# 0       Δίκη στο ΟΡΕΝ: Ανώνυμη επιστολή στην FIFA, μιλ...
# 1       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# 2       Κροατία: Η κυβέρνηση θέλει να ελέγξει τις δημο...
# 3       Ανώνυμη επιστολή στη FIFA για “διαφθορά στο ελ...
# 4       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# ...                                                   ...
# 166396             Ελπιδοφόρο το 2025 για τον ΣΥΡΙΖΑ Π.Σ.
# 166397  Φάρος ελπίδας, αλληλεγγύης, προόδου και κοινων...
# 166398  Οι ΗΠΑ ανακαλούν έκθεση σχετικά με το λιμό στη...
# 166399  Πλέγμα μέτρων για την ενδοοικογενειακή βία – Τ...
# 166400  Ισραήλ: Στο χειρουργείο ο Νετανιάχου – Θα υποβ...
#
#                                                      text        date  \
# 0       Από\nΧ. ΤΚ\nΗ\nFIFA\nέλαβε την προηγούμενη εβδ...  2024-01-15
# 1       Η FIFA έλαβε την προηγούμενη εβδομάδα μια ανών...  2024-01-15
# 2       Το νομοσχέδιο αναμένεται να ψηφιστεί στη νέα σ...  2024-01-15
# 3       Ανώνυμη επιστολή, η οποία ταχυδρομήθηκε από τη...  2024-01-15
# 4       NEWSLETTER\nNEWSLETTER\nNEWSLETTER\nΈρχεται Μο...  2024-01-15
# ...                                                   ...         ...
# 166396  Σημεία από την παρέμβαση του εκπροσώπου Τύπου ...  2024-12-28
# 166397  Επίσκεψη του Προέδρου του ΣΥΡΙΖΑ-ΠΣ, Σωκράτη Φ...  2024-12-28
# 166398  Μετά τα κροκοδείλια δάκρυα των ΗΠΑ για «ανθρωπ...  2024-12-28
# 166399  Σε δημόσια διαβούλευση τέθηκε το πλέγμα διατάξ...  2024-12-28
# 166400  Ισραήλ: Στο χειρουργείο ο Νετανιάχου – Θα υποβ...  2024-12-28
#
#             time                                               link  \
# 0       23:58:00  https://www.iapopsi.gr/diki-sto-oren-anonymi-e...
# 1       23:46:33  https://www.sfina.gr/anonumi-epistoli-sti-fifa...
# 2       23:46:22  https://www.pentapostagma.gr/kosmos/7216079_kr...
# 3       23:45:56  https://www.sportrikala.gr/2024/01/%ce%b1%ce%b...
# 4       23:44:41  https://thestandard.gr/athlitika/anonymi-epist...
# ...          ...                                                ...
# 166396  00:00:00  https://syriza.gr/elpidoforo-to-2025-gia-ton-s...
# 166397  00:00:00  https://syriza.gr/faros-elpidas-allilengyis-pr...
# 166398  00:00:00  https://www.imerodromos.gr/oi-ipa-anakaloyn-ek...
# 166399  00:00:00  https://epiloges.tv/plegma-metron-gia-thn-endo...
# 166400  00:00:00  https://athens-news.gr/%ce%b9%cf%83%cf%81%ce%b...
#
#        /content/gdrive/MyDrive/διαφθορα
# 0                           jan1-15.csv
# 1                           jan1-15.csv
# 2                           jan1-15.csv
# 3                           jan1-15.csv
# 4                           jan1-15.csv
# ...                                 ...
# 166396                     dec28-31.csv
# 166397                     dec28-31.csv
# 166398                     dec28-31.csv
# 166399                     dec28-31.csv
# 166400                     dec28-31.csv
#
# [166401 rows x 8 columns]

# %%
df_main= df_main[df_main["type"] == "web"].drop_duplicates(subset="title")

# %%
df_main
# Out:
#        type            source  \
# 0       web        iapopsi.gr
# 1       web          sfina.gr
# 2       web  pentapostagma.gr
# 3       web    sportrikala.gr
# 4       web    thestandard.gr
# ...     ...               ...
# 166392  web           skai.gr
# 166393  web       newmoney.gr
# 166396  web         syriza.gr
# 166397  web         syriza.gr
# 166398  web    imerodromos.gr
#
#                                                     title  \
# 0       Δίκη στο ΟΡΕΝ: Ανώνυμη επιστολή στην FIFA, μιλ...
# 1       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# 2       Κροατία: Η κυβέρνηση θέλει να ελέγξει τις δημο...
# 3       Ανώνυμη επιστολή στη FIFA για “διαφθορά στο ελ...
# 4       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# ...                                                   ...
# 166392  Όσα νομίζετε ότι ξέρετε για τον πόλεμο στην Ου...
# 166393  BBC: Στα βρετανικά πανεπιστήμια φοιτητές που μ...
# 166396             Ελπιδοφόρο το 2025 για τον ΣΥΡΙΖΑ Π.Σ.
# 166397  Φάρος ελπίδας, αλληλεγγύης, προόδου και κοινων...
# 166398  Οι ΗΠΑ ανακαλούν έκθεση σχετικά με το λιμό στη...
#
#                                                      text        date  \
# 0       Από\nΧ. ΤΚ\nΗ\nFIFA\nέλαβε την προηγούμενη εβδ...  2024-01-15
# 1       Η FIFA έλαβε την προηγούμενη εβδομάδα μια ανών...  2024-01-15
# 2       Το νομοσχέδιο αναμένεται να ψηφιστεί στη νέα σ...  2024-01-15
# 3       Ανώνυμη επιστολή, η οποία ταχυδρομήθηκε από τη...  2024-01-15
# 4       NEWSLETTER\nNEWSLETTER\nNEWSLETTER\nΈρχεται Μο...  2024-01-15
# ...                                                   ...         ...
# 166392  Φταίει η Δύση για τον πόλεμο στην Ουκρανία; Σύ...  2024-12-28
# 166393  Ανεπαρκείς γλωσσικές δεξιότητες, τεχνητή νοημο...  2024-12-28
# 166396  Σημεία από την παρέμβαση του εκπροσώπου Τύπου ...  2024-12-28
# 166397  Επίσκεψη του Προέδρου του ΣΥΡΙΖΑ-ΠΣ, Σωκράτη Φ...  2024-12-28
# 166398  Μετά τα κροκοδείλια δάκρυα των ΗΠΑ για «ανθρωπ...  2024-12-28
#
#             time                                               link  \
# 0       23:58:00  https://www.iapopsi.gr/diki-sto-oren-anonymi-e...
# 1       23:46:33  https://www.sfina.gr/anonumi-epistoli-sti-fifa...
# 2       23:46:22  https://www.pentapostagma.gr/kosmos/7216079_kr...
# 3       23:45:56  https://www.sportrikala.gr/2024/01/%ce%b1%ce%b...
# 4       23:44:41  https://thestandard.gr/athlitika/anonymi-epist...
# ...          ...                                                ...
# 166392  00:13:11  https://www.skai.gr/news/world/osa-nomizete-ot...
# 166393  00:00:27  https://www.newmoney.gr/roh/diethni/bbc-sta-vr...
# 166396  00:00:00  https://syriza.gr/elpidoforo-to-2025-gia-ton-s...
# 166397  00:00:00  https://syriza.gr/faros-elpidas-allilengyis-pr...
# 166398  00:00:00  https://www.imerodromos.gr/oi-ipa-anakaloyn-ek...
#
#        /content/gdrive/MyDrive/διαφθορα
# 0                           jan1-15.csv
# 1                           jan1-15.csv
# 2                           jan1-15.csv
# 3                           jan1-15.csv
# 4                           jan1-15.csv
# ...                                 ...
# 166392                     dec28-31.csv
# 166393                     dec28-31.csv
# 166396                     dec28-31.csv
# 166397                     dec28-31.csv
# 166398                     dec28-31.csv
#
# [112560 rows x 8 columns]

# %%
df_main = df_main.dropna(subset=["date"]).reset_index(drop=True)
df_main = df_main.dropna(subset=["text"]).reset_index(drop=True)
df_main = df_main.dropna(subset=["title"]).reset_index(drop=True)

# %%
df_main
# Out:
#        type            source  \
# 0       web        iapopsi.gr
# 1       web          sfina.gr
# 2       web  pentapostagma.gr
# 3       web    sportrikala.gr
# 4       web    thestandard.gr
# ...     ...               ...
# 108859  web           skai.gr
# 108860  web       newmoney.gr
# 108861  web         syriza.gr
# 108862  web         syriza.gr
# 108863  web    imerodromos.gr
#
#                                                     title  \
# 0       Δίκη στο ΟΡΕΝ: Ανώνυμη επιστολή στην FIFA, μιλ...
# 1       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# 2       Κροατία: Η κυβέρνηση θέλει να ελέγξει τις δημο...
# 3       Ανώνυμη επιστολή στη FIFA για “διαφθορά στο ελ...
# 4       Ανώνυμη επιστολή στη FIFA: «Διαφθορά και κατάχ...
# ...                                                   ...
# 108859  Όσα νομίζετε ότι ξέρετε για τον πόλεμο στην Ου...
# 108860  BBC: Στα βρετανικά πανεπιστήμια φοιτητές που μ...
# 108861             Ελπιδοφόρο το 2025 για τον ΣΥΡΙΖΑ Π.Σ.
# 108862  Φάρος ελπίδας, αλληλεγγύης, προόδου και κοινων...
# 108863  Οι ΗΠΑ ανακαλούν έκθεση σχετικά με το λιμό στη...
#
#                                                      text        date  \
# 0       Από\nΧ. ΤΚ\nΗ\nFIFA\nέλαβε την προηγούμενη εβδ...  2024-01-15
# 1       Η FIFA έλαβε την προηγούμενη εβδομάδα μια ανών...  2024-01-15
# 2       Το νομοσχέδιο αναμένεται να ψηφιστεί στη νέα σ...  2024-01-15
# 3       Ανώνυμη επιστολή, η οποία ταχυδρομήθηκε από τη...  2024-01-15
# 4       NEWSLETTER\nNEWSLETTER\nNEWSLETTER\nΈρχεται Μο...  2024-01-15
# ...                                                   ...         ...
# 108859  Φταίει η Δύση για τον πόλεμο στην Ουκρανία; Σύ...  2024-12-28
# 108860  Ανεπαρκείς γλωσσικές δεξιότητες, τεχνητή νοημο...  2024-12-28
# 108861  Σημεία από την παρέμβαση του εκπροσώπου Τύπου ...  2024-12-28
# 108862  Επίσκεψη του Προέδρου του ΣΥΡΙΖΑ-ΠΣ, Σωκράτη Φ...  2024-12-28
# 108863  Μετά τα κροκοδείλια δάκρυα των ΗΠΑ για «ανθρωπ...  2024-12-28
#
#             time                                               link  \
# 0       23:58:00  https://www.iapopsi.gr/diki-sto-oren-anonymi-e...
# 1       23:46:33  https://www.sfina.gr/anonumi-epistoli-sti-fifa...
# 2       23:46:22  https://www.pentapostagma.gr/kosmos/7216079_kr...
# 3       23:45:56  https://www.sportrikala.gr/2024/01/%ce%b1%ce%b...
# 4       23:44:41  https://thestandard.gr/athlitika/anonymi-epist...
# ...          ...                                                ...
# 108859  00:13:11  https://www.skai.gr/news/world/osa-nomizete-ot...
# 108860  00:00:27  https://www.newmoney.gr/roh/diethni/bbc-sta-vr...
# 108861  00:00:00  https://syriza.gr/elpidoforo-to-2025-gia-ton-s...
# 108862  00:00:00  https://syriza.gr/faros-elpidas-allilengyis-pr...
# 108863  00:00:00  https://www.imerodromos.gr/oi-ipa-anakaloyn-ek...
#
#        /content/gdrive/MyDrive/διαφθορα
# 0                           jan1-15.csv
# 1                           jan1-15.csv
# 2                           jan1-15.csv
# 3                           jan1-15.csv
# 4                           jan1-15.csv
# ...                                 ...
# 108859                     dec28-31.csv
# 108860                     dec28-31.csv
# 108861                     dec28-31.csv
# 108862                     dec28-31.csv
# 108863                     dec28-31.csv
#
# [108864 rows x 8 columns]

# %%
df_main['text'] = df_main['text'].str.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')

# %%
df_main.groupby("source")['title'].count().reset_index().sort_values("title", ascending=False).iloc[0:20, :]
# Out:
#                  source  title
# 1368          syriza.gr   2065
# 198      bankingnews.gr   1349
# 399            efsyn.gr   1247
# 1123    parapolitika.gr   1075
# 343    documentonews.gr   1009
# 1479       topontiki.gr    990
# 1109            palo.gr    940
# 662   hellasjournal.com    893
# 888         makeleio.gr    891
# 862            libre.gr    881
# 169      athens-news.gr    867
# 241          capital.gr    833
# 1013         newpost.gr    822
# 686       iefimerida.gr    779
# 1154   pentapostagma.gr    772
# 206       bci24news.com    766
# 1105        pagenews.gr    735
# 341            dnews.gr    729
# 889          makthes.gr    703
# 1472     tomanifesto.gr    674

# %%
# Βήμα 1: Βρες τους 20 top sources
top_sources = (
    df_main.groupby("source")['title']
    .count()
    .reset_index()
    .sort_values("title", ascending=False)
    .iloc[0:20, :]['source']
)

# Βήμα 2: Φίλτραρε το αρχικό DataFrame για να κρατήσεις μόνο τα άρθρα από αυτούς
df_top = df_main[df_main['source'].isin(top_sources)]

# %%
df_top=df_top.reset_index(drop=True)
df_top
# Out:
#                  source                                              title  \
# 0      pentapostagma.gr  Economist: Εκλογές σε περισσότερες από 70 χώρε...
# 1           makeleio.gr  ΟΛΑ ΤΑ ΕΙΧΑΜΕ, Η ΕΡΤ ΜΑΣ ΕΛΕΙΠΕ! ΑΙΣΧΡΟ ΝΤΑΒΑΤ...
# 2        bankingnews.gr  Economist: Το 2024 θα είναι... αγχωτικό για όσ...
# 3       parapolitika.gr  Ισραήλ: Απόφαση ''χαστούκι'' στον Μπενιαμίν Νε...
# 4              efsyn.gr  Δικαστικό χαστούκι για τη μεταρρύθμιση Νετανιά...
# ...                 ...                                                ...
# 19015        newpost.gr  Πολυτελές «ναρκοπάρτι» στα Καλύβια: H DJ-διακι...
# 19016       makeleio.gr  «8.5 εκατ. ΠΡΟΣΤΙΜΟ χώρια το ΜΕΡΟΚΑΜΑΤΟ». ΤΕΡΑ...
# 19017         syriza.gr  Καθαρισμός στο νοσοκομείο Ευαγγελισμός: Συνεχί...
# 19018          libre.gr  Βελιγράδι: Πρώην υπουργός Μεταφορών ανάμεσα στ...
# 19019  pentapostagma.gr  Με πολύ βαριά ατζέντα έρχεται στην Ελλάδα η Κί...
#
#                                                     text        date  \
# 0      Η υποψηφιότητα του Ντόναλντ Τραμπ υπονομεύει τ...  2024-01-01
# 1      Το ζήτημα της αύξησης του ανταποδοτικού τέλους...  2024-01-01
# 2      Το άρθρο του δημοφιλούς οικονομικού ιστότοπου ...  2024-01-01
# 3      Parapolitika Newsroom Το Ανώτατο Δικαστήριο το...  2024-01-01
# 4      Εν μέσω πολέμου και καθώς ο ισραηλινός στρατός...  2024-01-01
# ...                                                  ...         ...
# 19015  Ένα εντυπωσιακό πάρτι με ναρκωτικά αποκάλυψαν ...  2024-12-31
# 19016  ***Το πρακτορείο Άργος του ολιγάρχη Μαρινάκη κ...  2024-12-31
# 19017  Δήλωση του Βουλευτή Αχαΐας & Τομεάρχη Υγείας, ...  2024-12-31
# 19018  Ένας πρώην υπουργός της κυβέρνησης και πολλοί ...  2024-12-31
# 19019  Η Κιμπερλι έχει ήδη πέσει στα «βαθειά νερά» τω...  2024-12-31
#
#            time                                               link
# 0      23:42:52  https://www.pentapostagma.gr/kosmos/7213519_ec...
# 1      23:33:55  https://www.makeleio.gr/%ce%b5%ce%be%cf%89%cf%...
# 2      23:00:44     https://www.bankingnews.gr/index.php?id=713676
# 3      22:49:21  https://www.parapolitika.gr/diethni/article/13...
# 4      22:14:42  https://www.efsyn.gr/kosmos/mesi-anatoli/41712...
# ...         ...                                                ...
# 19015  07:18:38          https://newpost.gr/eidiseis/__trashed-11/
# 19016  02:47:09  https://www.makeleio.gr/%ce%b5%cf%80%ce%b9%ce%...
# 19017  00:00:00  https://syriza.gr/katharismos-sto-nosokomeio-e...
# 19018  13:03:33  https://www.libre.gr/2024/12/31/veligradi-proi...
# 19019  13:35:31  https://www.pentapostagma.gr/ethnika-themata/7...
#
# [19020 rows x 6 columns]
